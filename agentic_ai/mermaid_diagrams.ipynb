# %% [markdown]
# ```json
# {
#     "theme": "base",
#     "themeVariables": {
#         "primaryColor": "#BB2528",
#         "primaryTextColor": "#fff",
#         "primaryBorderColor": "#7C0000",
#         "lineColor": "#F8B229",
#         "secondaryColor": "#006100",
#         "tertiaryColor": "#fff"
#     }
# }
# ```

# %% [markdown]
# ```mermaid
# graph LR
#     subgraph manager_agent
#         A3[Managing Other Agents and save final file]
#         B3([file_write_tool <br> python_executor])
#         C3["HfApiModel('Qwen2.5-Coder-32B-Instruct')"]
#         C3 -- uses tool(s) --> B3 -- for --> A3
#     end
#
#     subgraph job_description_agent
#         A1[scrapes linkedin job page and summarizes JD]
#         B1([scrape_linkedin_job_page])
#         C1["HfApiModel('Qwen2.5-Coder-32B-Instruct')"]
#         C1 -- uses tool(s) --> B1 -- for --> A1
#     end
#
#     subgraph project_filter_agent
#         A2[reads project file and filters relavant projects]
#         B2([file_read_tool])
#         C2["HfApiModel('Qwen2.5-Coder-32B-Instruct')"]
#         C2 -- uses tool(s) --> B2 -- for --> A2
#     end
#
#     manager_agent -- manages --> job_description_agent
#     manager_agent -- manages --> project_filter_agent
#
#
#     classDef default text-align:center,font-family:arial
#     linkStyle default stroke: blue
# ```

# %% [markdown]
# ```mermaid
# graph LR
#     subgraph manager_agent
#         A3[Manage other agents and save the final file]
#         B3([file_write_tool <br> python_executor])
#         A3 -- using tool(s) --> B3
#     end
#
#     subgraph job_description_agent
#         A1[Scraping linkedin job page and summarizes JD]
#         B1([scrape_linkedin_job_page])
#         A1 -- using tool(s) --> B1
#     end
#
#     subgraph project_filter_agent
#         A2[Reading project file and filters relavant projects]
#         B2([file_read_tool])
#         A2 -- using tool(s) --> B2
#     end
#
#
#     manager_agent -- manages --> job_description_agent
#     manager_agent -- manages --> project_filter_agent
#
#
#     classDef default text-align:center,font-family:arial
#     linkStyle default stroke: blue
#
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#
# H[Human]
# L[LLM]
# T(Tools)
# E([Environment])
# End[END]
#
# subgraph LT [LLM + Tools]
#     direction LR
#     L --> T
#     end
#
# H <--> L
# T --> E
# E <--> L
# L --> End
# H --> End
#
# classDef default text-align:center,font-family:arial
# linkStyle default stroke: blue
#
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#
# H[Human]
# L[LLM]
# T(Tools)
# E([State])
# End[END]
#
# subgraph LT [LLM + Tools]
#     direction LR
#     L --Can Use--> T
#     end
#
# H --Prompts--> L
# L --Clarification--> H
# T <--Retrieve/Update--> E
# E <--Retrieves/Updates--> L
# L -- Can End --> End
# H -- Can End --> End
#
# classDef default text-align:center,font-family:arial
# linkStyle default stroke: blue
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#
# L((Large Language Model))
# I@{ shape: procs, label: "Text,<br>Image,<br>Audio,<br>Video"}
# O@{ shape: procs, label: "Text,<br>Image,<br>Audio,<br>Video"}
# subgraph inputs [Inputs]
#     I
#     end
#
# subgraph outputs [Outputs]
#     O
#     end
# I --> L --> O
#
# classDef default text-align:center,font-family:arial
# linkStyle default stroke: blue
# ```
